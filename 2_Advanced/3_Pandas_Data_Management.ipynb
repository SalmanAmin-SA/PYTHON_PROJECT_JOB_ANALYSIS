# %%
# importing libraries
import pandas as pd 
from datasets import load_dataset
import matplotlib.pyplot as plt 

# loading data 
dataset = load_dataset('lukebarousse/data_jobs')
df= dataset['train'].to_pandas()

# Data Cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.sample(10)
# Out:
#               job_title_short  \
# 509198   Senior Data Engineer
# 226171  Senior Data Scientist
# 161333          Data Engineer
# 539736           Data Analyst
# 565927      Software Engineer
# 574283    Senior Data Analyst
# 289095          Data Engineer
# 340127          Data Engineer
# 252845           Data Analyst
# 289335          Data Engineer
#
#                                                 job_title  \
# 509198                Senior Data Engineer (Fully-remote)
# 226171                              Senior Data Scientist
# 161333  Valiance Solutions - AWS Data Engineer - SQL/P...
# 539736              Supply Chain Data Analyst and Planner
# 565927                                        IT Engineer
# 574283                           Sr. Data Science Analyst
# 289095                                      Data Engineer
# 340127        HCMC - Data Engineer (Junior/Middle/Senior)
# 252845                                       Data Analyst
# 289335                                 Lead Data Engineer
#
#                        job_location          job_via  \
# 509198                     Anywhere     via LinkedIn
# 226171              Ankara, Türkiye     via LinkedIn
# 161333  Bengaluru, Karnataka, India     via LinkedIn
# 539736              Los Angeles, CA        via BeBee
# 565927                Málaga, Spain        via BeBee
# 574283                     Anywhere     via LinkedIn
# 289095            Bangkok, Thailand    via JOBTOPGUN
# 340127             Amares, Portugal  via Recruit.net
# 252845                Madrid, Spain  via Trabajo.org
# 289335              Dublin, Ireland  via Trabajo.org
#
#                            job_schedule_type  job_work_from_home  \
# 509198                             Full-time                True
# 226171                             Full-time               False
# 161333                             Full-time               False
# 539736                             Full-time               False
# 565927                             Full-time               False
# 574283                             Full-time                True
# 289095  Full-time, Contractor, and Temp work               False
# 340127                             Full-time               False
# 252845                             Full-time               False
# 289335                             Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 509198             United Kingdom 2023-06-13 11:12:34                  False
# 226171                     Turkey 2023-05-16 07:47:18                  False
# 161333                      India 2023-07-21 15:14:00                  False
# 539736  California, United States 2023-05-24 19:00:59                  False
# 565927                      Spain 2023-09-29 05:08:13                   True
# 574283                  Argentina 2023-07-12 09:19:47                  False
# 289095                   Thailand 2023-11-23 17:29:45                  False
# 340127                   Portugal 2023-08-29 23:48:29                  False
# 252845                      Spain 2023-09-02 07:35:46                   True
# 289335                    Ireland 2023-01-14 17:26:04                   True
#
#         job_health_insurance     job_country salary_rate  salary_year_avg  \
# 509198                 False  United Kingdom        None              NaN
# 226171                 False          Turkey        None              NaN
# 161333                 False           India        None              NaN
# 539736                 False   United States        None              NaN
# 565927                 False           Spain        None              NaN
# 574283                 False       Argentina        None              NaN
# 289095                 False        Thailand        None              NaN
# 340127                 False        Portugal        None              NaN
# 252845                 False           Spain        None              NaN
# 289335                 False         Ireland        None              NaN
#
#         salary_hour_avg                    company_name  \
# 509198              NaN                 RemoteWorker UK
# 226171              NaN                          Radius
# 161333              NaN              Valiance Solutions
# 539736              NaN             SILVUS TECHNOLOGIES
# 565927              NaN           Page Personnel España
# 574283              NaN                   Syneos Health
# 289095              NaN  บริษัท เอ็มเอสซี สิทธิผล จำกัด
# 340127              NaN                  MANTU GROUP SA
# 252845              NaN                         Iwantic
# 289335              NaN              Archer Recruitment
#
#                                                job_skills  \
# 509198   ['python', 'sql', 'snowflake', 'aws', 'airflow']
# 226171  ['python', 'sql', 'aws', 'django', 'flask', 'l...
# 161333  ['sql', 'python', 'aws', 'redshift', 'snowflak...
# 539736      ['spreadsheet', 'excel', 'sheets', 'planner']
# 565927                                 ['sql', 'windows']
# 574283  ['sql', 'sql server', 'azure', 'databricks', '...
# 289095   ['hadoop', 'kafka', 'spark', 'airflow', 'linux']
# 340127                                  ['sql', 'oracle']
# 252845                                               None
# 289335                                               None
#
#                                           job_type_skills
# 509198  {'cloud': ['snowflake', 'aws'], 'libraries': [...
# 226171  {'cloud': ['aws'], 'os': ['linux'], 'other': [...
# 161333  {'analyst_tools': ['tableau', 'power bi'], 'cl...
# 539736  {'analyst_tools': ['spreadsheet', 'excel', 'sh...
# 565927        {'os': ['windows'], 'programming': ['sql']}
# 574283  {'cloud': ['azure', 'databricks', 'snowflake']...
# 289095  {'libraries': ['hadoop', 'kafka', 'spark', 'ai...
# 340127      {'cloud': ['oracle'], 'programming': ['sql']}
# 252845                                               None
# 289335                                               None
