# %% [markdown]
# # Exercise - Analyzing Data Science Job Demand

# %%
# importing libraries
import pandas as pd 
from datasets import load_dataset
import matplotlib.pyplot as plt 

# loading data 
dataset = load_dataset('lukebarousse/data_jobs')
df= dataset['train'].to_pandas()

# Data Cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_US = df[df['job_country'] == 'United States'].copy()

# %%
df_US.sample(5)
# Out:
#               job_title_short  \
# 112361       Business Analyst
# 667227  Senior Data Scientist
# 626873         Data Scientist
# 707451          Data Engineer
# 394336    Senior Data Analyst
#
#                                                 job_title  \
# 112361                           Asset management analyst
# 667227          Senior/Principal Data Scientist - Finance
# 626873  Data Analytics - Data Scientist. Job in Elk Gr...
# 707451                            Principal Data Engineer
# 394336  Senior Tableau Consultant/Data Analyst (Public...
#
#                    job_location                   job_via job_schedule_type  \
# 112361             New York, NY            via Talent.com         Full-time
# 667227  South San Francisco, CA        via JobMonkey Jobs         Full-time
# 626873            Elk Grove, CA  via My Valley Jobs Today         Full-time
# 707451             Westlake, TX                  via Dice         Full-time
# 394336               Austin, TX                  via Dice        Contractor
#
#         job_work_from_home            search_location     job_posted_date  \
# 112361               False    New York, United States 2023-09-11 00:00:06
# 667227               False  California, United States 2023-02-12 10:05:12
# 626873               False  California, United States 2023-01-11 12:05:00
# 707451               False     Florida, United States 2023-02-13 02:11:01
# 394336               False       Texas, United States 2023-05-24 18:01:07
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 112361                  False                 False  United States
# 667227                  False                  True  United States
# 626873                  False                 False  United States
# 707451                  False                 False  United States
# 394336                   True                 False  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 112361        None              NaN              NaN
# 667227        None              NaN              NaN
# 626873        None              NaN              NaN
# 707451        None              NaN              NaN
# 394336        None              NaN              NaN
#
#                          company_name  \
# 112361  The Custom Group of Companies
# 667227                      Genentech
# 626873  Systems Integration Solutions
# 707451           Fidelity Investments
# 394336              Amtex System Inc.
#
#                                                job_skills  \
# 112361                       ['oracle', 'tableau', 'sap']
# 667227  ['python', 'r', 'aws', 'pandas', 'jupyter', 't...
# 626873                       ['sql', 'python', 'tableau']
# 707451                          ['oracle', 'aws', 'jira']
# 394336                                        ['tableau']
#
#                                           job_type_skills
# 112361  {'analyst_tools': ['tableau', 'sap'], 'cloud':...
# 667227  {'analyst_tools': ['tableau'], 'cloud': ['aws'...
# 626873  {'analyst_tools': ['tableau'], 'programming': ...
# 707451    {'async': ['jira'], 'cloud': ['oracle', 'aws']}
# 394336                     {'analyst_tools': ['tableau']}

# %%
df_US['job_posted_month'] = df_US['job_posted_date'].dt.strftime('%B') 

df_US
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# 785673                    Asset Management Data Scientist      New York, NY
# 785685                                       Data Analyst  Indianapolis, IN
# 785692               Data Scientist- Hybrid Work Location        Dayton, OH
# 785703            Data Analyst - CRYPTOGRAPHY - Full-time          Anywhere
# 785705          Expert Business Data Analyst - Now Hiring       Oakland, CA
#
#                   job_via         job_schedule_type  job_work_from_home  \
# 0         via Work Nearby                 Full-time               False
# 3       via Diversity.com                 Full-time               False
# 5        via ZipRecruiter  Contractor and Temp work                True
# 6            via LinkedIn                 Full-time               False
# 9        via ZipRecruiter                 Full-time                True
# ...                   ...                       ...                 ...
# 785673    via Trabajo.org                 Full-time               False
# 785685    via Trabajo.org                 Full-time               False
# 785692    via Ai-Jobs.net                 Full-time               False
# 785703       via Snagajob                 Full-time                True
# 785705       via Snagajob                 Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 0            Texas, United States 2023-06-16 13:44:15                  False
# 3            Texas, United States 2023-07-04 13:01:41                   True
# 5                         Georgia 2023-11-07 14:01:59                  False
# 6          Florida, United States 2023-03-27 13:18:18                  False
# 9         New York, United States 2023-04-23 13:02:57                  False
# ...                           ...                 ...                    ...
# 785673    New York, United States 2023-10-16 06:01:53                   True
# 785685    Illinois, United States 2023-07-16 06:01:27                   True
# 785692    Illinois, United States 2023-04-21 06:02:31                  False
# 785703       Texas, United States 2023-01-28 06:02:55                   True
# 785705  California, United States 2023-01-09 06:00:25                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                      False  United States        None              NaN
# 3                      False  United States        None              NaN
# 5                      False  United States        None              NaN
# 6                      False  United States        None              NaN
# 9                      False  United States        None              NaN
# ...                      ...            ...         ...              ...
# 785673                 False  United States        None              NaN
# 785685                 False  United States        None              NaN
# 785692                  True  United States        year         157500.0
# 785703                 False  United States        None              NaN
# 785705                 False  United States        None              NaN
#
#         salary_hour_avg                   company_name  \
# 0                   NaN           Boehringer Ingelheim
# 3                   NaN   Southwest Research Institute
# 5                   NaN                smart folks inc
# 6                   NaN  Miracle Software Systems, Inc
# 9                   NaN     Radwell International, LLC
# ...                 ...                            ...
# 785673              NaN           JPMorgan Chase & Co.
# 785685              NaN         Aara Technologies, Inc
# 785692              NaN                         Tenet3
# 785703              NaN    Axelon Services Corporation
# 785705              NaN               PG&E Corporation
#
#                                                job_skills  \
# 0                                                    None
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                ['python', 'sql', 'gcp']
# 6       ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9       ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# ...                                                   ...
# 785673                                               None
# 785685                                   ['sql', 'excel']
# 785692                          ['python', 'matlab', 'r']
# 785703                                               None
# 785705                       ['sql', 'python', 'tableau']
#
#                                           job_type_skills job_posted_month
# 0                                                    None             June
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...             July
# 5       {'cloud': ['gcp'], 'programming': ['python', '...         November
# 6       {'cloud': ['gcp', 'bigquery'], 'databases': ['...            March
# 9       {'analyst_tools': ['excel'], 'cloud': ['azure'...            April
# ...                                                   ...              ...
# 785673                                               None          October
# 785685  {'analyst_tools': ['excel'], 'programming': ['...             July
# 785692         {'programming': ['python', 'matlab', 'r']}            April
# 785703                                               None          January
# 785705  {'analyst_tools': ['tableau'], 'programming': ...          January
#
# [206292 rows x 18 columns]

# %%
df_US_pivot = df_US.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

# %%
df_US_pivot.reset_index(inplace=True)
df_US_pivot['month_number'] = pd.to_datetime(df_US_pivot['job_posted_month'], format ='%B').dt.month
df_US_pivot['month_number']
# Out:
# 0      4
# 1      8
# 2     12
# 3      2
# 4      1
# 5      7
# 6      6
# 7      3
# 8      5
# 9     11
# 10    10
# 11     9
# Name: month_number, dtype: int32

# %%
df_US_pivot.sort_values('month_number', inplace=True)
df_US_pivot.set_index('job_posted_month', inplace=True )
df_US_pivot.drop(columns='month_number', inplace=True)

# %%
df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    2655            6915                         60
# February                   3060            4956                         56
# March                      3183            4779                         59
# April                      2801            4867                         51
# May                        2976            4377                         49
# June                       2893            4645                         48
# July                       2570            4876                         65
# August                     3269            6318                         68
# September                  3224            4568                        113
# October                    3015            4882                        101
# November                   2793            4175                        132
# December                   2641            3472                        119
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                          1544                   773
# February                         1258                   878
# March                            1114                   829
# April                            1025                   781
# May                               839                   746
# June                             1009                   812
# July                              883                   747
# August                           1186                   903
# September                         805                   775
# October                           871                   672
# November                          656                   684
# December                          601                   689
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# January                            1552                114
# February                           1127                 90
# March                              1150                115
# April                               991                112
# May                                 914                 90
# June                               1033                 93
# July                               1095                153
# August                             1515                194
# September                          1014                228
# October                             987                219
# November                            816                194
# December                            752                212

# %%
df_US_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
top_3 = df_US['job_title_short'].value_counts().head(3)
top_3 = top_3.index.to_list()
top_3
# Out:
# ['Data Analyst', 'Data Scientist', 'Data Engineer']

# %%
df_US_pivot[top_3].plot(kind='line')
plt.title('Monthly Job Postings for Top Data Jobs in the US')
plt.xlabel('2023')
plt.ylabel('Number of Job Postings')
plt.show()

# %%
df_US_pivot[top_3].plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='job_posted_month'>
